# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-AHMAD07/ML_Lab/blob/main/ML(Lab_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Challange Task 1

# %%
x=input("Enter Your First Name")
print("Hello")
print(x)
# Out:
# Enter Your First NameMuhammad
# Hello
# Muhammad

# %% [markdown]
# Challange Task 2

# %%
fname=input("Enter Your First Name")
lname=input("Enter Your Last Name")
print("Hello")
print(fname+" "+lname)
# Out:
# Enter Your First NameMuhammad
# Enter Your Last NameAhmad
# Hello
# Muhammad Ahmad

# %% [markdown]
# Challange Task 3

# %%
print("What do you call a bear with no teeth? \n A gummy bear!")
# Out:
# What do you call a bear with no teeth?
#  A gummy bear!

# %% [markdown]
# Challange Task 4

# %%
a1=input("Enter Your First Number")
a2=input("Enter Your Second Number")
a3=int(a1)+int(a2)
print("The total is",a3)
# Out:
# Enter Your First Number20
# Enter Your Second Number20
# The total is 40

# %% [markdown]
# Challange Task 4

# %%
a1=input("Enter Your First Number")
a2=input("Enter Your Second Number")
a3=int(a1)+int(a2)
a4=input("Enter Your Third Number")
a5=int(a3)*int(a4)
print("The answer is",a5)
# Out:
# Enter Your First Number4
# Enter Your Second Number5
# Enter Your Third Number6
# The answer is 54

# %% [markdown]
# Challange Task 6

# %%
p1=input("Enter the Number Of Slices You Took")
p2=input("Enter the Total Number Of Slices You Eaten")
p3=int(p1)-int(p2)
print("You have",p3,"Slices Left")
# Out:
# Enter the Number Of Slices You Took6
# Enter the Total Number Of Slices You Eaten5
# You have 1 Slices Left

# %% [markdown]
# Challange Task 7

# %%
n1=input("Enter Your Name")
n2=input("Enter Your Age")
n3=int(n2)+1
print(n1,"Next Birthday You Will Be",n3)
# Out:
# Enter Your NameAhmad
# Enter Your Age21
# Ahmad Next Birthday You Will Be 22

# %% [markdown]
# Challange Task 8

# %%
b=input("Enter the Total Amount Of the Bill")
b1=input("Enter the Total Pesons Who Went To The Dinner")
b2=int(b)/int(b1)
print("Each Person Will have to Pay",b2)
# Out:
# Enter the Total Amount Of the Bill1500
# Enter the Total Pesons Who Went To The Dinner3
# Each Person Will have to Pay 500.0

# %% [markdown]
# Challange Task 9

# %%
days=input("Enter the Number Of Days")
hours=int(days)*24
minutes=int(hours)*60
seconds=int(minutes)*60
print(days,"Days Has",hours,"Hours",minutes,"Minutes",seconds,"Seconds")
# Out:
# Enter the Number Of Days4
# 4 Days Has 96 Hours 5760 Minutes 345600 Seconds

# %% [markdown]
# Challanage Task 10

# %%
w=input("Enter Your Weight In kgs")
p=int(w)*2.204
print("Your Weight In Pounds Is",p)
# Out:
# Enter Your Weight In kgs60
# Your Weight In Pounds Is 132.24

# %% [markdown]
# Challange Task 11

# %%
n1=input("Enter Number from 0 to 100:")
n2=input("Enter an other Number from 0 to 10:")
n3=int(n1)//int(n2)
print(n2,"Will Take",n3,"To reach",n1)
# Out:
# Enter Number from 0 to 100:100
# Enter an other Number from 0 to 10:10
# 10 Will Take 10 To reach 100

# %% [markdown]
# Challange Task 12

# %%
n1=input("Enter First Number")
n2=input("Enter Second Number")
if n1>n2:
    print(n2)
    print(n1)
else:
    print(n1)
    print(n2)
# Out:
# Enter First Number5
# Enter Second Number7
# 5
# 7

# %% [markdown]
# Challange Task 13

# %%
a1=input("Enter a number Between 0 to 20 ")
if int(a1)<20:
    print("Thank You")
else:
  print("Too High")
# Out:
# Enter a number Between 0 to 20 1
# Thank You

# %% [markdown]
# Challange Task 14

# %%
a2 = input("Enter a number between 10 to 20: ")
num = int(a2)

if 10 < num < 20:
    print("Thank You")
else:
    print("Incorrect Ans")
# Out:
# Enter a number between 10 to 20: 20
# Incorrect Ans

# %% [markdown]
# Challange Task 15

# %%
color = input("Enter your favorite color: ")
if color == "red" and "RED" and "Red":
    print("I like red too")
else:
  print("I dont like ",color,", I prefer Red")
# Out:
# Enter your favorite color: yellow
# I dont like  yellow , I prefer Red

# %% [markdown]
# Challange Task 16

# %%
q1 = input("Is it raining? ").lower()
if q1 == "yes":
    q2 = input("Is it windy? ").lower()
    if q2 == "yes":
        print("It is too windy for an umbrella")
    else:
        print("Take an umbrella")
else:
    print("Enjoy your day")
# Out:
# Is it raining? YES
# Is it windy? YES
# It is too windy for an umbrella

# %% [markdown]
# challange Task 17

# %%
age = int(input("Enter age:"))
if age >= 18:
  print("You can vote")
elif age == 17:
  print("You can learn to drive")
elif age == 16:
  print("You can buy A  lottery ticket")
else:
  print("You can go Trick or Treating")
# Out:
# Enter age:22
# You can vote

# %% [markdown]
# Challange Task 18

# %%
num = int(input("Enter a number"))
if num <10:
  print("Too low")
elif num >=10 and num <= 20:
  print("Correct")
else:
  print("Too high")
# Out:
# Enter a number7
# Too low

# %% [markdown]
# Challange Task 19

# %%
choice = input("Enter 1, 2 or 3: ")

if choice == "1":
    print("Thank you")
elif choice == "2":
    print("Well done")
elif choice == "3":
    print("Correct")
else:
    print("Error message")
# Out:
# Enter 1, 2 or 3: 3
# Correct

# %% [markdown]
# Challange Task 20

# %%
n1=input("Enter Your First Name")
length=len(n1)
print("The Total Length Of Your name is",length)
# Out:
# Enter Your First NameMuhammad
# The Total Length Of Your name is 8

# %% [markdown]
# Challange Task 21

# %%
fn=input("Enter your First Name:")
sn=input("Enter your surname:")
name=fn+""+sn
print(name, "\nLength:", len(name))
# Out:
# Enter your First Name:Muhammad
# Enter your surname:Ahmad
# MuhammadAhmad
# Length: 13

# %% [markdown]
# Challange Task 22

# %%
first_name = input("Enter your first name in lower case: ")
surname = input("Enter your surname in lower case: ")

first_name = first_name.title()
surname = surname.title()

full_name = first_name + " " + surname

print(full_name)
# Out:
# Enter your first name in lower case: muhammad
# Enter your surname in lower case: ahmad
# Muhammad Ahmad

# %% [markdown]
# Challange Task 23

# %%
ask = input("Enter first line of a nursery rhyme")
print(len(ask))
start = int(input("Enter starting number"))
end = int(input("Enter ending number"))
print(ask[start:end])
# Out:
# Enter first line of a nursery rhymetwinkle twinkle
# 15
# Enter starting number2
# Enter ending number4
# in

# %% [markdown]
# Challange Task 24

# %%
w1=input("Write Something")
print(w1.upper())
# Out:
# Write Somethingbasil
# BASIL

# %% [markdown]
# Challange Task 25

# %%
first_name = input("Enter your first name: ")

if len(first_name) < 5:
    surname = input("Enter your surname: ")
    full_name = first_name + surname
    print(full_name.upper())
else:
    print(first_name.lower())
# Out:
# Enter your first name: Muhammad
# muhammad

# %% [markdown]
# Challange Task 26

# %%
word = input("Enter a word: ").lower()
vowels = "aeiou"
if word and word[0] in vowels:
    pig_latin = word + "way"
else:
    pig_latin = word[1:] + word[0] + "ay"

print(pig_latin)
# Out:
# Enter a word: ahmad
# ahmadway

# %% [markdown]
# Chalange Task 27

# %%
number=float(input("Enter a Number with Many decimal places"))
n3=number*2
print(n3)
# Out:
# Enter a Number with Many decimal places2.666
# 5.332

# %% [markdown]
# Challange Task 28

# %%
number=float(input("Enter a Number with Many decimal places"))
n3=number*2
print(round(n3,2))
# Out:
# Enter a Number with Many decimal places3.4567
# 6.91

# %% [markdown]
# Challange task 29

# %%
import math
number = int(input("Enter an integer over 500: "))
square_root = math.sqrt(number)
print(f"{square_root:.2f}")
# Out:
# Enter an integer over 500: 502
# 22.41

# %% [markdown]
# Challange Task 30

# %%
import math
print(round(math.pi,5))
# Out:
# 3.14159

# %% [markdown]
# Challange Task 31

# %%
radius=input("Enter radius Of Circle")
area=3.14*int(radius)**2
print(area)
# Out:
# Enter radius Of Circle4
# 50.24

# %% [markdown]
# Challange Task 32

# %%
r=input("Enter Radius:")
d=input("Enter Depth:")
a=math.pi*int(r)*2
v=int(a)*int(d)
print("Volume:", round(v,3))
# Out:
# Enter Radius:4
# Enter Depth:10
# Volume: 250

# %% [markdown]
# Challange Task 33

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

quotient = num1 // num2
remainder = num1 % num2

print(f"{num1} divided by {num2} is {quotient} with {remainder} remaining")
# Out:
# Enter first number: 222
# Enter second number: 111
# 222 divided by 111 is 2 with 0 remaining

# %% [markdown]
# Challange Task 34

# %%
print("1) Square")
print("2) Triangle")
choice = input("Enter a number: ")

if choice == "1":
    side = float(input("Enter the length of one side: "))
    area = side * side
    print("The area of the square is", area)
elif choice == "2":
    base = float(input("Enter the base: "))
    height = float(input("Enter the height: "))
    area = (base * height) / 2
    print("The area of the triangle is", area)
else:
    print("Invalid choice – please enter 1 or 2")
# Out:
# 1) Square
# 2) Triangle
# Enter a number: 1
# Enter the length of one side: 4
# The area of the square is 16.0
